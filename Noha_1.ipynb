# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Noha Abdulwahab Zamaan** </p>
# My job is Data Officer in Data Management Office in Ministry of Hajj and Umrah

# %% [markdown]
# *I am interested in data science because helps to solve problem , using data to produce the insight for it and predict the future*

# %% [markdown]
# ### In this code, I tried to convet Fahrenheit degree (F) to Celsius degree (C)

# %%
f= 70
print("The Fahrenheit Degree is: ",f)
c=(f-32)/1.8
print("The Celsius Degree is: ",int(c))
# Out:
# The Fahrenheit Degree is:  70
# The Celsius Degree is:  21

# %% [markdown]
# 1.
# |First Name|Last Name|
# |----------|----------|
# |Noha      |Zamaan   |
#
#
# 2.
# - Machine Learning
# - Deep Learning
# - Data Mining
#
# 3.
# [Coursera](https://www.coursera.org/programs/mbdr-t-zyz-lmsr-lwzyfy-otpaz?authProvider=nelc)
